# %% [markdown]
# # SRL Stemma for Sentence
#
# **Sentence:** The dog chased the cat across the yard.
#
# *************************************************
# llm interpreats this as sequence of the words but  context enginer using SRL sees
# like this
# ******************
# ## Semantic Roles
# - **Main action / (Predicate)  (Action):** chased
# - **Agent (Doer):** dog
# - **Patient (Object):** cat
# - **Location:** across the yard
#
# ## Stemma / Graph
#
# ```text
#            chased
#           /     \
#        dog       cat
#                    \
#                  across the yard

# %% [raw]
# Main action is the central node.
# - Other words branch out with their semantic roles.
# - Converts linear sentence into hierarchical semantic structure

# %% [markdown]
# Building an SRL notebook in Python

# %% [markdown]
# The purpose of this Python script is to take the essential parts of a sentence and turn them into
# a visual diagram of meaning. Rather than leaving structure hidden in text, the program draws a
# picture of the relationships between words and roles.

# %%
from IPython.display import Image, display
display(Image('../media/Flowchart_SRL_program.png'))
